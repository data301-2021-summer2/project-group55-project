# %%
import pandas as pd
df=pd.read_csv("C:/Users/UX305/data301/data301Project/project-group55-project/data/raw/AirQualityUCI/AirQualityUCI.csv",sep=';',decimal=',')
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df=df.dropna(how='all') ##Last several rows filled with NaN, need to remove them first.
df=df.dropna(how='all',axis='columns') #Last two unnanmed columns also need to be removed.
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
## By looking at the data, I find that there are several columns seems not really useful for me. I decide to remove them.
l1=['PT08.S1(CO)','PT08.S2(NMHC)','PT08.S3(NOx)','PT08.S4(NO2)','PT08.S5(O3)']
df2=df.drop(columns=l1)
df2
# Out:
#             Date      Time  CO(GT)  NMHC(GT)  C6H6(GT)  NOx(GT)  NO2(GT)  \
# 0     10/03/2004  18.00.00     2.6     150.0      11.9    166.0    113.0
# 1     10/03/2004  19.00.00     2.0     112.0       9.4    103.0     92.0
# 2     10/03/2004  20.00.00     2.2      88.0       9.0    131.0    114.0
# 3     10/03/2004  21.00.00     2.2      80.0       9.2    172.0    122.0
# 4     10/03/2004  22.00.00     1.6      51.0       6.5    131.0    116.0
# ...          ...       ...     ...       ...       ...      ...      ...
# 9352  04/04/2005  10.00.00     3.1    -200.0      13.5    472.0    190.0
# 9353  04/04/2005  11.00.00     2.4    -200.0      11.4    353.0    179.0
# 9354  04/04/2005  12.00.00     2.4    -200.0      12.4    293.0    175.0
# 9355  04/04/2005  13.00.00     2.1    -200.0       9.5    235.0    156.0
# 9356  04/04/2005  14.00.00     2.2    -200.0      11.9    265.0    168.0
#
#          T    RH      AH
# 0     13.6  48.9  0.7578
# 1     13.3  47.7  0.7255
# ...

# %%
#Want to sort the rows in month
df2['Date']=pd.to_datetime(df2['Date']).dt.date
df2['Month']=pd.DatetimeIndex(df2['Date']).month
#Extract month from the 'Date' column Reference:
##https://www.codegrepper.com/code-examples/python/extract+month+from+datetime+pandas
##problems occur!
df2
# Out:
#             Date      Time  CO(GT)  NMHC(GT)  C6H6(GT)  NOx(GT)  NO2(GT)  \
# 0     2004-10-03  18.00.00     2.6     150.0      11.9    166.0    113.0
# 1     2004-10-03  19.00.00     2.0     112.0       9.4    103.0     92.0
# 2     2004-10-03  20.00.00     2.2      88.0       9.0    131.0    114.0
# 3     2004-10-03  21.00.00     2.2      80.0       9.2    172.0    122.0
# 4     2004-10-03  22.00.00     1.6      51.0       6.5    131.0    116.0
# ...          ...       ...     ...       ...       ...      ...      ...
# 9352  2005-04-04  10.00.00     3.1    -200.0      13.5    472.0    190.0
# 9353  2005-04-04  11.00.00     2.4    -200.0      11.4    353.0    179.0
# 9354  2005-04-04  12.00.00     2.4    -200.0      12.4    293.0    175.0
# 9355  2005-04-04  13.00.00     2.1    -200.0       9.5    235.0    156.0
# 9356  2005-04-04  14.00.00     2.2    -200.0      11.9    265.0    168.0
#
#          T    RH      AH  Month
# 0     13.6  48.9  0.7578     10
# ...

# %%
df2=df2.rename(columns={'CO(GT)':'CO C(mg/m^3)','NMHC(GT)':'NMHC C(mg/m^3)',
               'C6H6(GT)':'C6H6 C(mg/m^3)','NOx(GT)':'NOx C(ppb)','NO2(GT)':'NO2 C(mg/m^3)'})
df2
# Out:
#             Date      Time  CO C(mg/m^3)  NMHC C(mg/m^3)  C6H6 C(mg/m^3)  \
# 0     2004-10-03  18.00.00           2.6           150.0            11.9
# 1     2004-10-03  19.00.00           2.0           112.0             9.4
# 2     2004-10-03  20.00.00           2.2            88.0             9.0
# 3     2004-10-03  21.00.00           2.2            80.0             9.2
# 4     2004-10-03  22.00.00           1.6            51.0             6.5
# ...          ...       ...           ...             ...             ...
# 9352  2005-04-04  10.00.00           3.1          -200.0            13.5
# 9353  2005-04-04  11.00.00           2.4          -200.0            11.4
# 9354  2005-04-04  12.00.00           2.4          -200.0            12.4
# 9355  2005-04-04  13.00.00           2.1          -200.0             9.5
# 9356  2005-04-04  14.00.00           2.2          -200.0            11.9
#
#       NOx C(ppb)  NO2 C(mg/m^3)     T    RH      AH  Month
# ...

# %%
#Task2: Method chaining
DF=(pd.read_csv("C:/Users/UX305/data301/data301Project/project-group55-project/data/raw/AirQualityUCI/AirQualityUCI.csv",sep=';',decimal=',').
     rename(columns={'CO(GT)':'CO C(mg/m^3)','NMHC(GT)':'NMHC C(mg/m^3)',
               'C6H6(GT)':'C6H6 C(mg/m^3)','NOx(GT)':'NOx C(ppb)','NO2(GT)':'NO2 C(mg/m^3)'}).
     dropna(how='all').
     dropna(how='all',axis='columns').
     drop(columns=['PT08.S1(CO)','PT08.S2(NMHC)','PT08.S3(NOx)','PT08.S4(NO2)','PT08.S5(O3)']).
    assign(Date=lambda df_:pd.to_datetime(df_['Date']),
          month=lambda df_:pd.DatetimeIndex(df_['Date']).month))
#Lambda functions reference:https://stackabuse.com/lambda-functions-in-python

# %%
def load_and_process(url_or_path_to_csv_file):
    ## rename columns and dropping NaN columns and rows
    DF1= (pd.read_csv(url_or_path_to_csv_file,sep=';',decimal=',')
        .rename(columns={'CO(GT)':'CO C(mg/m^3)','NMHC(GT)':'NMHC C(mg/m^3)',
               'C6H6(GT)':'C6H6 C(mg/m^3)','NOx(GT)':'NOx C(ppb)','NO2(GT)':'NO2 C(mg/m^3)'})
        .dropna(how='all')
        .dropna(how='all',axis='columns'))
    ##Dropping other columns, convert to datetime object and adding new columns
    DF2=(DF1.drop(columns=['PT08.S1(CO)','PT08.S2(NMHC)','PT08.S3(NOx)','PT08.S4(NO2)','PT08.S5(O3)',
                          'C6H6 C(mg/m^3)','NOx C(ppb)','NMHC C(mg/m^3)','CO C(mg/m^3)'])
        .assign(Date=lambda df_:pd.to_datetime(df_['Date']),
          month=lambda df_:pd.DatetimeIndex(df_['Date']).month)
         .drop(DF1.index[(DF1['NO2 C(mg/m^3)']==-200.0)].tolist(),axis=0)
        )
    return DF2

# %%
#test output
load_and_process("C:/Users/UX305/data301/data301Project/project-group55-project/data/raw/AirQualityUCI/AirQualityUCI.csv")
# Out:
#            Date      Time  NO2 C(mg/m^3)     T    RH      AH  month
# 0    2004-10-03  18.00.00          113.0  13.6  48.9  0.7578     10
# 1    2004-10-03  19.00.00           92.0  13.3  47.7  0.7255     10
# 2    2004-10-03  20.00.00          114.0  11.9  54.0  0.7502     10
# 3    2004-10-03  21.00.00          122.0  11.0  60.0  0.7867     10
# 4    2004-10-03  22.00.00          116.0  11.2  59.6  0.7888     10
# ...         ...       ...            ...   ...   ...     ...    ...
# 9352 2005-04-04  10.00.00          190.0  21.9  29.3  0.7568      4
# 9353 2005-04-04  11.00.00          179.0  24.3  23.7  0.7119      4
# 9354 2005-04-04  12.00.00          175.0  26.9  18.3  0.6406      4
# 9355 2005-04-04  13.00.00          156.0  28.3  13.5  0.5139      4
# 9356 2005-04-04  14.00.00          168.0  28.5  13.1  0.5028      4
#
# [7715 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ind=df2.index[(df2['T']==-200.0)].tolist()
df4=df2.drop(ind,axis=0)
df4=df4.drop(columns=['C6H6 C(mg/m^3)','NOx C(ppb)','NMHC C(mg/m^3)','CO C(mg/m^3)'])
df4=df4.drop(df4.index[(df4['NO2 C(mg/m^3)']==-200.0)].tolist(),axis=0)
df4
##Drop abnormal row with temp=-200 degree
##Source:https://kanoki.org/2020/01/21/pandas-dataframe-filter-with-multiple-conditions/
# Out:
#             Date      Time  NO2 C(mg/m^3)     T    RH      AH  Month
# 0     2004-10-03  18.00.00          113.0  13.6  48.9  0.7578     10
# 1     2004-10-03  19.00.00           92.0  13.3  47.7  0.7255     10
# 2     2004-10-03  20.00.00          114.0  11.9  54.0  0.7502     10
# 3     2004-10-03  21.00.00          122.0  11.0  60.0  0.7867     10
# 4     2004-10-03  22.00.00          116.0  11.2  59.6  0.7888     10
# ...          ...       ...            ...   ...   ...     ...    ...
# 9352  2005-04-04  10.00.00          190.0  21.9  29.3  0.7568      4
# 9353  2005-04-04  11.00.00          179.0  24.3  23.7  0.7119      4
# 9354  2005-04-04  12.00.00          175.0  26.9  18.3  0.6406      4
# 9355  2005-04-04  13.00.00          156.0  28.3  13.5  0.5139      4
# 9356  2005-04-04  14.00.00          168.0  28.5  13.1  0.5028      4
#
# [7393 rows x 7 columns]

# %%
def catagorize(x):
    return int(x['T'])
df4.apply(catagorize,axis='columns')
df4['int T']=df4.apply(catagorize,axis='columns')
df4
##define new method that convert all the temp into integer so that the barplot looks much more neat.
# Out:
#             Date      Time  NO2 C(mg/m^3)     T    RH      AH  Month  int T
# 0     2004-10-03  18.00.00          113.0  13.6  48.9  0.7578     10     13
# 1     2004-10-03  19.00.00           92.0  13.3  47.7  0.7255     10     13
# 2     2004-10-03  20.00.00          114.0  11.9  54.0  0.7502     10     11
# 3     2004-10-03  21.00.00          122.0  11.0  60.0  0.7867     10     11
# 4     2004-10-03  22.00.00          116.0  11.2  59.6  0.7888     10     11
# ...          ...       ...            ...   ...   ...     ...    ...    ...
# 9352  2005-04-04  10.00.00          190.0  21.9  29.3  0.7568      4     21
# 9353  2005-04-04  11.00.00          179.0  24.3  23.7  0.7119      4     24
# 9354  2005-04-04  12.00.00          175.0  26.9  18.3  0.6406      4     26
# 9355  2005-04-04  13.00.00          156.0  28.3  13.5  0.5139      4     28
# 9356  2005-04-04  14.00.00          168.0  28.5  13.1  0.5028      4     28
#
# [7393 rows x 8 columns]

# %%
plt.figure(figsize=(14,9))
sns.barplot(x='int T',y='NO2 C(mg/m^3)',data=df4)
##There are no trend that with higher temperature, NO2 concentration will also go up.
# Out:
# <AxesSubplot:xlabel='int T', ylabel='NO2 C(mg/m^3)'>

# %%
plt.figure(figsize=(10,8))
Nitrogen = df4.pivot_table(index='Month', columns='Time', values='NO2 C(mg/m^3)')
sns.heatmap(Nitrogen, cmap='Blues', linecolor='white',linewidth=1)
###There are low No2 concentration in early morning around 1am to 6am
##the concentration of NO2 from Nov to Mar seems higher than in other times.
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Month'>

# %%
plt.figure(figsize=(10,8))
Air_mx = df4.corr()
sns.heatmap(Air_mx, annot=True, cmap='Blues')
## Proof the statement that NO2 concentration is not related to the temp
## NO2 also doesn't relate to AH and RH
# Out:
# <AxesSubplot:>

# %%
# Improvement on EDA (milestone 3)
## add plot type for visualization for plot 1, we want to change it from bar plot to scatter plot with trend line.
plt.figure(figsize=(8,8))
additional_plot= sns.lmplot(
data=df4,
x='T',y='NO2 C(mg/m^3)',height=5,markers='o',scatter_kws={"s": 1.5},line_kws={'color': 'black'}).set(
    xlabel='Temperature (°C)',ylabel='NO2 concentration(mg/m³)',title='Scatter Plot with linear trend line for the NO2 concentration in various temperature')
#Avoiding overplotting by reduce marker size.
sns.set_theme(context='paper',style='ticks',font_scale=1.25)
##The trend line indicates that there is a negative relatioship between Temperature and NO2 concentration in the air.
##The trend line does not fit in the plot as points lie broadly in the plot
##This proves that there is no significant evidence indocates that there is a linear relationship between temperature and NO2 concentration.

# %%
#Fixing bar plot
plt.figure(figsize=(14,9))
sns.barplot(x='int T',y='NO2 C(mg/m^3)',data=df4,color='red',saturation=0.6).set(xlabel='Temperature (°C)',ylabel='NO2 concentration(mg/m³)',
                                                                                   title='Barplotfor the NO2 concentration in various temperature conditions')
# Out:
# [Text(0.5, 0, 'Temperature (°C)'),
#  Text(0, 0.5, 'NO2 concentration(mg/m³)'),
#  Text(0.5, 1.0, 'Barplotfor the NO2 concentration in various temperature conditions')]

# %%
#Slightly editing for heatmap
plt.figure(figsize=(14,6))
Nitrogen = df4.pivot_table(index='Month', columns='Time', values='NO2 C(mg/m^3)')
sns.heatmap(Nitrogen, cmap='Blues',square= True,linecolor='white',linewidth=1,cbar_kws={'label': 'NO2 comcemtration(mg/m³)'}).set(
title='Heatmap of NO2 Concentration in Different Time and Month')
# Out:
# [Text(0.5, 1.0, 'Heatmap of NO2 Concentration in Different Time and Month')]

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x='RH',y='NO2 C(mg/m^3)',data=df4,s=10).set(xlabel='Relative Humidity(%)',ylabel='NO2 concentration(mg/m³)',
                                                           title='Scatter plot for NO2 concentration in various Relative Humidity')
sns.despine()
##As all points lie in most of the area of the plot with no order. It is obvious that there is no real relationship exist btween relative humidity and NO2 concentration.

# %%
## Export final dataframe into a csv file
df4.to_csv('Procced_dataset.csv', index=False)
